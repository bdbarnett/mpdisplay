# %%
import path
import mpdisplay_simpletest
# Out:
# path.py:  Added ['lib', 'extras', 'examples', 'app_configs'] to sys.path.
#
# MPDisplay:  Using JNDisplay
# <PIL.Image.Image image mode=RGB size=320x240>
